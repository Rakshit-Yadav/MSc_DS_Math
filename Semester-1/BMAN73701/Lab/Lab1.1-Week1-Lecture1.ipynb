# %% [markdown]
# # Exercise - 1

# %% [markdown]
# ### a) Printing hello hello hello using 3 different method

# %%
# First Method
print("hello hello hello")
# Out:
# hello hello hello

# %%
# Second Method
print('hello','hello','hello')
# Out:
# hello hello hello

# %%
# Third Method
print('hello '*3)

# %% [markdown]
# ### b) print hello world like this
# hello \n
# world!

# %%
print('hello\nworld!')
# Out:
# hello
# world!

# %% [markdown]
# ## Python as a calculator

# %%
print(3+4)
print(2**4)
print(5%2)
print(36**0.5)
# Out:
# 7
# 16
# 1
# 6.0

# %%
import math as m
m.sqrt(36)
# Out:
# 6.0

# %%
m.log(32,2) #this means
# Out:
# 5.0

# %%
m.cos(0) #just the value of cos(0)
# Out:
# 1.0

# %%
m.pow(2,4) # this means 2 raise to the power 4
# Out:
# 16.0

# %%
a = 3*5
b = a/10
print(b)
# this here is called the assignment operator (=)
# Out:
# 1.5

# %% [markdown]
# # Exercise - 2

# %% [markdown]
# ## a) Calculate 2-9 * 11

# %%
2-9*11
# Out:
# -97

# %% [markdown]
# ## b) Calcualte (2-9) * 11

# %%
(2-9)*11
# Out:
# -77

# %% [markdown]
# ## c) Calculate the positive root of the following equation:
# ## 34*x^2+68*x−510

# %%
# first we assign the values by considering it with the standard
# equation a * x^2 + b * x + c
a = 34
b = 68
c = -510

# now the basic solution for a quadratic equation is:
# x = (-b + square root(4*a*c))/(2*a)

# to use the square root there are 2 methods
# 1. use **0.5
# 2. import math module and use .sqrt function

import math
x = (-b+math.sqrt(b**2 - (4*a*c)))/(2*a)
print("The positive root of the equation is:",x)
# Out:
# The positive root of the equation is: 3.0

# %% [markdown]
# # Exercise - 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# we use the input() function to prompt the user for input.
name = input("What is your name: ")
city = input("What city do you live in: ")
country = input("What is your country of residence: ")
print("Nice to meet you",name,"from",city,",",country)
age = int(input("What's your age: "))
compliment_age = int(0.8*age)
print("Wow! You look like you could be",compliment_age,"!")
# Out:
# Nice to meet you Rakshit Yadav from Delhi , India
# Wow! You look like you could be 16 !

# %% [markdown]
# # Exercise - 4

# %% [markdown]
# ## The question is below:

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
divide_by = 2
subtract_by = 3
import math

var = int(input('Please provide an integer between 1 and 10: '))
var1 = var - subtract_by
print("Subtracting your value of",var,"by",subtract_by,"will give",var1)

var2 = var1 / divide_by
print("Dividing",var1,"by",divide_by,"will give",var2)

var3 = float(input("Please provide a real number between 0 and 1: "))
print("The ceiling of",var3,"is",math.ceil(var3))

var4 = int(input("Please provide an integer between 1 and 10: "))
var5 = int(input("Please provide an integer between 1 and 10: "))
print("Multiplying",var4,'by',var5,'will give',str(var4)*var5)
print('Multiplying',var4,'by',var5,'will give',var4*var5)
print('Multiplying',float(var4),'by',float(var5),'will give',float(var4*var5))
# Out:
# Please provide an integer between 1 and 10: 1
# Subtracting your value of 1 by 3 will give -2
# Dividing -2 by 2 will give -1.0
# Please provide a real number between 0 and 1: 0.5
# The ceiling of 0.5 is 1
# Please provide an integer between 1 and 10: 2
# Please provide an integer between 1 and 10: 3
# Multiplying 2 by 3 will give 222
# Multiplying 2 by 3 will give 6
# Multiplying 2.0 by 3.0 will give 6.0
